# %%
import pandas as pd

# %%
df = pd.read_csv("data/Multi_Agency_Response_to_Community_Hotspot__MARCH__Inspections.csv")
df
# Out:
#     Location ID ZIP Code        Borough  Council district  \
# 0             1   11,105         Queens                22
# 1             1   10,037      Manhattan                 9
# 2             2   10,027      Manhattan                 9
# 3             3   10,030      Manhattan                 9
# 4             4   10,463      The Bronx                11
# 5             5   10,302  Staten Island                49
# 6             6   10,302  Staten Island                49
# 7             7   11,103         Queens                22
# 8             8   11,103         Queens                22
# 9             9   11,103         Queens                26
# 10           10   10,459      The Bronx                17
# 11           11   10,459      The Bronx                17
# 12           12   11,210       Brooklyn                45
# 13           13   10,452      The Bronx                14
# 14           14   10,457      The Bronx                14
# ...
